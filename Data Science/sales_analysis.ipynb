# %% [markdown]
# ## Sales Analysis Practice

# %% [markdown]
# #### Import all necessary libraries

# %%
import pandas as pd
import os, sys

# %% [markdown]
# #### Merging 12 Months of Sales Data into a single file

# %%
df = pd.read_csv("./Sales_Data/Sales_April_2019.csv")

path = ('./Sales_Data')

files = [file for file in os.listdir(path)]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('./Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data, df])

# %%
all_months_data.to_csv("all_data.csv", index =False)
all_months_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# ### Read in updated dataframe

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# ### Augment data with additional collumns

# %% [markdown]
# ### Clean up Data First

# %% [markdown]
# #### Drop rows of NaN

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()

all_data = all_data.dropna(how='all')
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address Month
# 0  136 Church St, New York City, NY 10001    12
# 1     562 2nd St, New York City, NY 10001    12
# 2    277 Main St, New York City, NY 10001    12
# 3     410 6th St, San Francisco, CA 94016    12
# 4           43 Hill St, Atlanta, GA 30301    12

# %% [markdown]
# ### Find 'Or' and delete it
# #### Convert 'Month' value to int so we can later filter with it

# %%
all_data = all_data[all_data['Order Date'].str[0:2] !='Or']
all_data['Month']=all_data['Month'].astype('int32')
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address  Month
# 0  136 Church St, New York City, NY 10001     12
# 1     562 2nd St, New York City, NY 10001     12
# 2    277 Main St, New York City, NY 10001     12
# 3     410 6th St, San Francisco, CA 94016     12
# 4           43 Hill St, Atlanta, GA 30301     12

# %% [markdown]
# ##### Convert columns to the correct type

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])

#### pd.to_numeric is better than .astype because it'll automatically figure out what int type to use

all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# #### Task 3: Add a sales column

# %%
all_data['Sales'] = all_data['Price Each'] * all_data['Price Each']
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month         Sales
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12  2.890000e+06
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12  3.600000e+05
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12  1.428025e+02
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12  2.249700e+04
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12  1.428025e+02

# %% [markdown]
# ### Question 1: What was the best month for sales? How much was earned that month?

# %%
results = all_data.groupby('Month').sum()

# %% [markdown]
# #### Let's plot it

# %%
import matplotlib.pyplot as plt

months = range (1,13) ### 13 is exclusive so it's (1,12)

plt.bar(months, results['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD (Millions $)')
plt.xlabel('Month number')

plt.show()

# %% [markdown]
# #### Task 4: Add a city column

# %%
### Let's use .apply()

all_data['Column'] = all_data['Purchase Address'].apply(lambda x: x.split(',')[1])
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12
#
#           Sales                                    City          Column
# 0  2.890000e+06  136 Church St, New York City, NY 10001   New York City
# 1  3.600000e+05     562 2nd St, New York City, NY 10001   New York City
# 2  1.428025e+02    277 Main St, New York City, NY 10001   New York City
# 3  2.249700e+04     410 6th St, San Francisco, CA 94016   San Francisco
# 4  1.428025e+02           43 Hill St, Atlanta, GA 30301         Atlanta

# %% [markdown]
# #### Question 2: What city had the highest number of sales

# %%
all_data['City'] = all_data['Purchase Address']
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12
#
#           Sales                                    City
# 0  2.890000e+06  136 Church St, New York City, NY 10001
# 1  3.600000e+05     562 2nd St, New York City, NY 10001
# 2  1.428025e+02    277 Main St, New York City, NY 10001
# 3  2.249700e+04     410 6th St, San Francisco, CA 94016
# 4  1.428025e+02           43 Hill St, Atlanta, GA 30301
